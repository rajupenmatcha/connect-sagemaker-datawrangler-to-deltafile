# %%
# Notebook that shows how you can connect sagemaker to deltalake through the "Athena" connector in SM data wrangler

# %%
# install needed libraries

# %%
pip install delta-spark
# Out:
# Requirement already satisfied: delta-spark in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.0.0)
# Requirement already satisfied: importlib-metadata>=3.10.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from delta-spark) (4.8.1)
# Requirement already satisfied: pyspark<3.2.0,>=3.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from delta-spark) (3.1.2)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=3.10.0->delta-spark) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=3.10.0->delta-spark) (3.10.0.2)
# Requirement already satisfied: py4j==0.10.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pyspark<3.2.0,>=3.1.0->delta-spark) (0.10.9)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# get spark session that automatically downloads delta jars
import pyspark
from delta import *

builder = pyspark.sql.SparkSession.builder.appName("MyApp") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
# load the input csv file
df = spark.read.csv("./SampleSuperstore.csv", header = 'True', inferSchema = True)

# %%
df.limit(5).toPandas()
# Out:
#          ShipMode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    PostalCode Region         Category Sub-Category     Sales  Quantity  \
# 0       42420  South        Furniture    Bookcases  261.9600         2
# 1       42420  South        Furniture       Chairs  731.9400         3
# 2       90036   West  Office Supplies       Labels   14.6200         2
# 3       33311  South        Furniture       Tables  957.5775         5
# 4       33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
# Write dataframe in delta format
df.write.format("delta").mode("overwrite").save("./delta/")

# %%
# Generate MANIFEST file for Athena/Catalog
deltaTable = DeltaTable.forPath(spark, "./delta/")
deltaTable.generate("symlink_format_manifest")

# %%
# Update local manifest file to link to S3
s3_bucket = "mybucket"
s3_prefix = "datawrangler/athena/deltalake/delta/"
def point_manifestfile_to_s3(fn, s3_bucket, s3_prefix):
    with open(fn) as f:
        line = f.readlines()[0]
        newline = line[line.find("part"):]
        newline = "s3://" + s3_bucket + "/" + s3_prefix + newline
        #print(newline)
        f.close()
    f = open(fn, "w")
    f.write(newline)
    f.close()
point_manifestfile_to_s3("./delta/_symlink_format_manifest/manifest", s3_bucket, s3_prefix)

# %%
# Upload local files to S3 bucket
import os
import boto3

s3_resource = boto3.resource("s3", region_name="us-east-1")

def upload_objects(bucket_name, prefix, root_path):
    try:
        my_bucket = s3_resource.Bucket(bucket_name)

        for path, subdirs, files in os.walk(root_path):
            path = path.replace("\\","/")
            directory_name = path.replace(root_path,"")
            for file in files:
                if directory_name != "":
                    my_bucket.upload_file(os.path.join(path, file), prefix + directory_name+'/'+file)
                else:
                    my_bucket.upload_file(os.path.join(path, file), prefix +file)

    except Exception as err:
        print(err)
upload_objects("mybucket", "datawrangler/athena/deltalake/delta/", "./delta/")

# %%
# Run Athena now

# %%
import boto3
import time
import json
import pprint
import sys

# Defaults
query_output = 's3://mybucket/datawrangler/athena/deltalake/delta/outputs'
pp = pprint.PrettyPrinter(indent=2)
queryparams = {}
queryparams['execution_id']=''
athena = boto3.client('athena')

# functions
# queryparams is mutable, so that execution_id has to be returned to the caller for further processing
def run_athena_query (query, queryparams):
    print("Executing query:\n{0}".format(query))
    response = athena.start_query_execution(
        QueryString=query,
        ResultConfiguration={
            'OutputLocation': query_output
        }
    )
    execution_id = response['QueryExecutionId']
    queryparams['execution_id'] = execution_id
    status = ''
    while True:
        stats = athena.get_query_execution(QueryExecutionId=execution_id)
        status = stats['QueryExecution']['Status']['State']
        if status in ['SUCCEEDED', 'FAILED', 'CANCELLED']:
            return status
        time.sleep(0.2)  # 200ms

# Print the results of the query execution
def print_results(execution_id):
    results = athena.get_query_results(QueryExecutionId=execution_id)
    print (json.dumps(results, sort_keys=True, indent=4))

def run_athena():
    query = r'''CREATE EXTERNAL TABLE IF NOT EXISTS default.superstore2 ( 
shipmode STRING,
segment STRING,
country STRING,
city STRING,
state STRING,
postalcode int,
region STRING,
category STRING,
subcategory STRING,
sales double,
quantity int,
discount double,
profit double
) ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe' 
STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
LOCATION 's3://temp-rp-2020/datawrangler/athena/deltalake/delta2/_symlink_format_manifest/'
    '''
    # 'org.openx.data.jsonserde.JsonSerDe'
    queryparams['execution_id']=''
    if run_athena_query(query, queryparams) !=  'SUCCEEDED' :
        print (ret)
        sys.exit(1)

    print_results(queryparams['execution_id'])

    # Now interrogate the data
    query = r'''
    SELECT
        * 
    FROM default.superstore2
    '''

    queryparams['execution_id']=''
    ret = run_athena_query(query, queryparams)
    if ret !=  'SUCCEEDED' :
        print (ret)
        sys.exit(1)
    print_results(queryparams['execution_id'])

# end functions
run_athena()
# Out:
# Executing query:
# CREATE EXTERNAL TABLE IF NOT EXISTS default.superstore2 (
# shipmode STRING,
# segment STRING,
# country STRING,
# city STRING,
# state STRING,
# postalcode int,
# region STRING,
# category STRING,
# subcategory STRING,
# sales double,
# quantity int,
# discount double,
# profit double
# ) ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://temp-rp-2020/datawrangler/athena/deltalake/delta2/_symlink_format_manifest/'
#
# {
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "connection": "keep-alive",
#             "content-length": "108",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Sun, 05 Dec 2021 23:38:18 GMT",
#             "x-amzn-requestid": "e0d44558-e102-4c4e-a085-ce28b7b6264a"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "e0d44558-e102-4c4e-a085-ce28b7b6264a",
#         "RetryAttempts": 0
#     },
#     "ResultSet": {
#         "ResultSetMetadata": {
#             "ColumnInfo": []
#         },
#         "Rows": []
#     }
# }
# Executing query:
#
#     SELECT
#         *
#     FROM default.superstore2
#
# {
#     "NextToken": "AVpPVZSKKUoWQUNAnYOUNOy1LGuwAcXi0p0QrYG3r0rNEZ/2B4pp6pWRV/rKyw6Qvil/fwzcNhzTXKZ3gYNVyHZxnKL+rQcNHw==",
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "connection": "keep-alive",
#             "content-length": "493456",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Sun, 05 Dec 2021 23:38:20 GMT",
#             "x-amzn-requestid": "225e486a-d543-4ab6-a711-52b1ab6b7b53"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "225e486a-d543-4ab6-a711-52b1ab6b7b53",
#         "RetryAttempts": 0
#     },
#     "ResultSet": {
#         "ResultSetMetadata": {
#             "ColumnInfo": [
#                 {
#                     "CaseSensitive": true,
#                     "CatalogName": "hive",
#                     "Label": "shipmode",
#                     "Name": "shipmode",
#                     "Nullable": "UNKNOWN",
#                     "Precision": 2147483647,
#                     "Scale": 0,
#                     "SchemaName": "",
#                     "TableName": "",
#                     "Type": "varchar"
#                 },
#                 {
#                     "CaseSensitive": true,
#                     "CatalogName": "hive",
#                     "Label": "segment",
#                     "Name": "segment",
#                     "Nullable": "UNKNOWN",
#                     "Precision": 2147483647,
#                     "Scale": 0,
#                     "SchemaName": "",
#                     "TableName": "",
#                     "Type": "varchar"
#                 },
#                 {
#                     "CaseSensitive": true,
#                     "CatalogName": "hive",
#                     "Label": "country",
#                     "Name": "country",
#                     "Nullable": "UNKNOWN",
#                     "Precision": 2147483647,
#                     "Scale": 0,
#                     "SchemaName": "",
#                     "TableName": "",
#                     "Type": "varchar"
#                 },
#                 {
#                     "CaseSensitive": true,
#                     "CatalogName": "hive",
#                     "Label": "city",
#                     "Name": "city",
#                     "Nullable": "UNKNOWN",
#                     "Precision": 2147483647,
#                     "Scale": 0,
#                     "SchemaName": "",
#                     "TableName": "",
#                     "Type": "varchar"
#                 },
#                 {
#                     "CaseSensitive": true,
#                     "CatalogName": "hive",
#                     "Label": "state",
#                     "Name": "state",
#                     "Nullable": "UNKNOWN",
#                     "Precision": 2147483647,
#                     "Scale": 0,
#                     "SchemaName": "",
#                     "TableName": "",
#                     "Type": "varchar"
#                 },
#                 {
#                     "CaseSensitive": false,
#                     "CatalogName": "hive",
#                     "Label": "postalcode",
#                     "Name": "postalcode",
#                     "Nullable": "UNKNOWN",
#                     "Precision": 10,
#                     "Scale": 0,
#                     "SchemaName": "",
#                     "TableName": "",
#                     "Type": "integer"
#                 },
#                 {
#                     "CaseSensitive": true,
#                     "CatalogName": "hive",
#                     "Label": "region",
#                     "Name": "region",
#                     "Nullable": "UNKNOWN",
#                     "Precision": 2147483647,
#                     "Scale": 0,
#                     "SchemaName": "",
#                     "TableName": "",
#                     "Type": "varchar"
#                 },
#                 {
#                     "CaseSensitive": true,
#                     "CatalogName": "hive",
#                     "Label": "category",
#                     "Name": "category",
#                     "Nullable": "UNKNOWN",
#                     "Precision": 2147483647,
#                     "Scale": 0,
#                     "SchemaName": "",
#                     "TableName": "",
#                     "Type": "varchar"
#                 },
#                 {
#                     "CaseSensitive": true,
#                     "CatalogName": "hive",
#                     "Label": "subcategory",
#                     "Name": "subcategory",
#                     "Nullable": "UNKNOWN",
#                     "Precision": 2147483647,
#                     "Scale": 0,
#                     "SchemaName": "",
#                     "TableName": "",
#                     "Type": "varchar"
#                 },
#                 {
#                     "CaseSensitive": false,
#                     "CatalogName": "hive",
#                     "Label": "sales",
#                     "Name": "sales",
#                     "Nullable": "UNKNOWN",
#                     "Precision": 17,
#                     "Scale": 0,
#                     "SchemaName": "",
#                     "TableName": "",
#                     "Type": "double"
#                 },
#                 {
#                     "CaseSensitive": false,
#                     "CatalogName": "hive",
#                     "Label": "quantity",
#                     "Name": "quantity",
#                     "Nullable": "UNKNOWN",
#                     "Precision": 10,
#                     "Scale": 0,
#                     "SchemaName": "",
#                     "TableName": "",
#                     "Type": "integer"
#                 },
#                 {
#                     "CaseSensitive": false,
#                     "CatalogName": "hive",
#                     "Label": "discount",
#                     "Name": "discount",
#                     "Nullable": "UNKNOWN",
#                     "Precision": 17,
#                     "Scale": 0,
#                     "SchemaName": "",
#                     "TableName": "",
#                     "Type": "double"
#                 },
#                 {
#                     "CaseSensitive": false,
#                     "CatalogName": "hive",
#                     "Label": "profit",
#                     "Name": "profit",
#                     "Nullable": "UNKNOWN",
#                     "Precision": 17,
#                     "Scale": 0,
#                     "SchemaName": "",
#                     "TableName": "",
#                     "Type": "double"
#                 }
#             ]
#         },
#         "Rows": [
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "shipmode"
#                     },
#                     {
#                         "VarCharValue": "segment"
#                     },
#                     {
#                         "VarCharValue": "country"
#                     },
#                     {
#                         "VarCharValue": "city"
#                     },
#                     {
#                         "VarCharValue": "state"
#                     },
#                     {
#                         "VarCharValue": "postalcode"
#                     },
#                     {
#                         "VarCharValue": "region"
#                     },
#                     {
#                         "VarCharValue": "category"
#                     },
#                     {
#                         "VarCharValue": "subcategory"
#                     },
#                     {
#                         "VarCharValue": "sales"
#                     },
#                     {
#                         "VarCharValue": "quantity"
#                     },
#                     {
#                         "VarCharValue": "discount"
#                     },
#                     {
#                         "VarCharValue": "profit"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Second Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Henderson"
#                     },
#                     {
#                         "VarCharValue": "Kentucky"
#                     },
#                     {
#                         "VarCharValue": "42420"
#                     },
#                     {
#                         "VarCharValue": "South"
#                     },
#                     {
#                         "VarCharValue": "Furniture"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "261.96"
#                     },
#                     {
#                         "VarCharValue": "2"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "41.9136"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Second Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Henderson"
#                     },
#                     {
#                         "VarCharValue": "Kentucky"
#                     },
#                     {
#                         "VarCharValue": "42420"
#                     },
#                     {
#                         "VarCharValue": "South"
#                     },
#                     {
#                         "VarCharValue": "Furniture"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "731.94"
#                     },
#                     {
#                         "VarCharValue": "3"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "219.582"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Second Class"
#                     },
#                     {
#                         "VarCharValue": "Corporate"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Los Angeles"
#                     },
#                     {
#                         "VarCharValue": "California"
#                     },
#                     {
#                         "VarCharValue": "90036"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "14.62"
#                     },
#                     {
#                         "VarCharValue": "2"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "6.8714"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Fort Lauderdale"
#                     },
#                     {
#                         "VarCharValue": "Florida"
#                     },
#                     {
#                         "VarCharValue": "33311"
#                     },
#                     {
#                         "VarCharValue": "South"
#                     },
#                     {
#                         "VarCharValue": "Furniture"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "957.5775"
#                     },
#                     {
#                         "VarCharValue": "5"
#                     },
#                     {
#                         "VarCharValue": "0.45"
#                     },
#                     {
#                         "VarCharValue": "-383.031"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Fort Lauderdale"
#                     },
#                     {
#                         "VarCharValue": "Florida"
#                     },
#                     {
#                         "VarCharValue": "33311"
#                     },
#                     {
#                         "VarCharValue": "South"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "22.368"
#                     },
#                     {
#                         "VarCharValue": "2"
#                     },
#                     {
#                         "VarCharValue": "0.2"
#                     },
#                     {
#                         "VarCharValue": "2.5164"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Los Angeles"
#                     },
#                     {
#                         "VarCharValue": "California"
#                     },
#                     {
#                         "VarCharValue": "90032"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Furniture"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "48.86"
#                     },
#                     {
#                         "VarCharValue": "7"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "14.1694"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Los Angeles"
#                     },
#                     {
#                         "VarCharValue": "California"
#                     },
#                     {
#                         "VarCharValue": "90032"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "7.28"
#                     },
#                     {
#                         "VarCharValue": "4"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "1.9656"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Los Angeles"
#                     },
#                     {
#                         "VarCharValue": "California"
#                     },
#                     {
#                         "VarCharValue": "90032"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Technology"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "907.152"
#                     },
#                     {
#                         "VarCharValue": "6"
#                     },
#                     {
#                         "VarCharValue": "0.2"
#                     },
#                     {
#                         "VarCharValue": "90.7152"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Los Angeles"
#                     },
#                     {
#                         "VarCharValue": "California"
#                     },
#                     {
#                         "VarCharValue": "90032"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "18.504"
#                     },
#                     {
#                         "VarCharValue": "3"
#                     },
#                     {
#                         "VarCharValue": "0.2"
#                     },
#                     {
#                         "VarCharValue": "5.7825"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Los Angeles"
#                     },
#                     {
#                         "VarCharValue": "California"
#                     },
#                     {
#                         "VarCharValue": "90032"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "114.9"
#                     },
#                     {
#                         "VarCharValue": "5"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "34.47"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Los Angeles"
#                     },
#                     {
#                         "VarCharValue": "California"
#                     },
#                     {
#                         "VarCharValue": "90032"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Furniture"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "1706.184"
#                     },
#                     {
#                         "VarCharValue": "9"
#                     },
#                     {
#                         "VarCharValue": "0.2"
#                     },
#                     {
#                         "VarCharValue": "85.3092"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Los Angeles"
#                     },
#                     {
#                         "VarCharValue": "California"
#                     },
#                     {
#                         "VarCharValue": "90032"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Technology"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "911.424"
#                     },
#                     {
#                         "VarCharValue": "4"
#                     },
#                     {
#                         "VarCharValue": "0.2"
#                     },
#                     {
#                         "VarCharValue": "68.3568"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Concord"
#                     },
#                     {
#                         "VarCharValue": "North Carolina"
#                     },
#                     {
#                         "VarCharValue": "28027"
#                     },
#                     {
#                         "VarCharValue": "South"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "15.552"
#                     },
#                     {
#                         "VarCharValue": "3"
#                     },
#                     {
#                         "VarCharValue": "0.2"
#                     },
#                     {
#                         "VarCharValue": "5.4432"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Seattle"
#                     },
#                     {
#                         "VarCharValue": "Washington"
#                     },
#                     {
#                         "VarCharValue": "98103"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "407.976"
#                     },
#                     {
#                         "VarCharValue": "3"
#                     },
#                     {
#                         "VarCharValue": "0.2"
#                     },
#                     {
#                         "VarCharValue": "132.5922"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Home Office"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Fort Worth"
#                     },
#                     {
#                         "VarCharValue": "Texas"
#                     },
#                     {
#                         "VarCharValue": "76106"
#                     },
#                     {
#                         "VarCharValue": "Central"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "68.81"
#                     },
#                     {
#                         "VarCharValue": "5"
#                     },
#                     {
#                         "VarCharValue": "0.8"
#                     },
#                     {
#                         "VarCharValue": "-123.858"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Home Office"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Fort Worth"
#                     },
#                     {
#                         "VarCharValue": "Texas"
#                     },
#                     {
#                         "VarCharValue": "76106"
#                     },
#                     {
#                         "VarCharValue": "Central"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "2.544"
#                     },
#                     {
#                         "VarCharValue": "3"
#                     },
#                     {
#                         "VarCharValue": "0.8"
#                     },
#                     {
#                         "VarCharValue": "-3.816"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Madison"
#                     },
#                     {
#                         "VarCharValue": "Wisconsin"
#                     },
#                     {
#                         "VarCharValue": "53711"
#                     },
#                     {
#                         "VarCharValue": "Central"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "665.88"
#                     },
#                     {
#                         "VarCharValue": "6"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "13.3176"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Second Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "West Jordan"
#                     },
#                     {
#                         "VarCharValue": "Utah"
#                     },
#                     {
#                         "VarCharValue": "84084"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "55.5"
#                     },
#                     {
#                         "VarCharValue": "2"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "9.99"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Second Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "San Francisco"
#                     },
#                     {
#                         "VarCharValue": "California"
#                     },
#                     {
#                         "VarCharValue": "94109"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "8.56"
#                     },
#                     {
#                         "VarCharValue": "2"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "2.4824"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Second Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "San Francisco"
#                     },
#                     {
#                         "VarCharValue": "California"
#                     },
#                     {
#                         "VarCharValue": "94109"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Technology"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "213.48"
#                     },
#                     {
#                         "VarCharValue": "3"
#                     },
#                     {
#                         "VarCharValue": "0.2"
#                     },
#                     {
#                         "VarCharValue": "16.011"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Second Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "San Francisco"
#                     },
#                     {
#                         "VarCharValue": "California"
#                     },
#                     {
#                         "VarCharValue": "94109"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "22.72"
#                     },
#                     {
#                         "VarCharValue": "4"
#                     },
#                     {
#                         "VarCharValue": "0.2"
#                     },
#                     {
#                         "VarCharValue": "7.384"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Corporate"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Fremont"
#                     },
#                     {
#                         "VarCharValue": "Nebraska"
#                     },
#                     {
#                         "VarCharValue": "68025"
#                     },
#                     {
#                         "VarCharValue": "Central"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "19.46"
#                     },
#                     {
#                         "VarCharValue": "7"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "5.0596"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Corporate"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Fremont"
#                     },
#                     {
#                         "VarCharValue": "Nebraska"
#                     },
#                     {
#                         "VarCharValue": "68025"
#                     },
#                     {
#                         "VarCharValue": "Central"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "60.34"
#                     },
#                     {
#                         "VarCharValue": "7"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "15.6884"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Second Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Philadelphia"
#                     },
#                     {
#                         "VarCharValue": "Pennsylvania"
#                     },
#                     {
#                         "VarCharValue": "19140"
#                     },
#                     {
#                         "VarCharValue": "East"
#                     },
#                     {
#                         "VarCharValue": "Furniture"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "71.372"
#                     },
#                     {
#                         "VarCharValue": "2"
#                     },
#                     {
#                         "VarCharValue": "0.3"
#                     },
#                     {
#                         "VarCharValue": "-1.0196"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Orem"
#                     },
#                     {
#                         "VarCharValue": "Utah"
#                     },
#                     {
#                         "VarCharValue": "84057"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Furniture"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "1044.63"
#                     },
#                     {
#                         "VarCharValue": "3"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "240.2649"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Second Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Los Angeles"
#                     },
#                     {
#                         "VarCharValue": "California"
#                     },
#                     {
#                         "VarCharValue": "90049"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "11.648"
#                     },
#                     {
#                         "VarCharValue": "2"
#                     },
#                     {
#                         "VarCharValue": "0.2"
#                     },
#                     {
#                         "VarCharValue": "4.2224"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Second Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Los Angeles"
#                     },
#                     {
#                         "VarCharValue": "California"
#                     },
#                     {
#                         "VarCharValue": "90049"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Technology"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "90.57"
#                     },
#                     {
#                         "VarCharValue": "3"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "11.7741"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Philadelphia"
#                     },
#                     {
#                         "VarCharValue": "Pennsylvania"
#                     },
#                     {
#                         "VarCharValue": "19140"
#                     },
#                     {
#                         "VarCharValue": "East"
#                     },
#                     {
#                         "VarCharValue": "Furniture"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "3083.43"
#                     },
#                     {
#                         "VarCharValue": "7"
#                     },
#                     {
#                         "VarCharValue": "0.5"
#                     },
#                     {
#                         "VarCharValue": "-1665.0522"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Philadelphia"
#                     },
#                     {
#                         "VarCharValue": "Pennsylvania"
#                     },
#                     {
#                         "VarCharValue": "19140"
#                     },
#                     {
#                         "VarCharValue": "East"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "9.618"
#                     },
#                     {
#                         "VarCharValue": "2"
#                     },
#                     {
#                         "VarCharValue": "0.7"
#                     },
#                     {
#                         "VarCharValue": "-7.0532"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Philadelphia"
#                     },
#                     {
#                         "VarCharValue": "Pennsylvania"
#                     },
#                     {
#                         "VarCharValue": "19140"
#                     },
#                     {
#                         "VarCharValue": "East"
#                     },
#                     {
#                         "VarCharValue": "Furniture"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "124.2"
#                     },
#                     {
#                         "VarCharValue": "3"
#                     },
#                     {
#                         "VarCharValue": "0.2"
#                     },
#                     {
#                         "VarCharValue": "15.525"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Philadelphia"
#                     },
#                     {
#                         "VarCharValue": "Pennsylvania"
#                     },
#                     {
#                         "VarCharValue": "19140"
#                     },
#                     {
#                         "VarCharValue": "East"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "3.264"
#                     },
#                     {
#                         "VarCharValue": "2"
#                     },
#                     {
#                         "VarCharValue": "0.2"
#                     },
#                     {
#                         "VarCharValue": "1.1016"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Philadelphia"
#                     },
#                     {
#                         "VarCharValue": "Pennsylvania"
# ...
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Pasadena"
#                     },
#                     {
#                         "VarCharValue": "Texas"
#                     },
#                     {
#                         "VarCharValue": "77506"
#                     },
#                     {
#                         "VarCharValue": "Central"
#                     },
#                     {
#                         "VarCharValue": "Technology"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "336.51"
#                     },
#                     {
#                         "VarCharValue": "3"
#                     },
#                     {
#                         "VarCharValue": "0.4"
#                     },
#                     {
#                         "VarCharValue": "44.868"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Same Day"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Houston"
#                     },
#                     {
#                         "VarCharValue": "Texas"
#                     },
#                     {
#                         "VarCharValue": "77041"
#                     },
#                     {
#                         "VarCharValue": "Central"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "1.112"
#                     },
#                     {
#                         "VarCharValue": "2"
#                     },
#                     {
#                         "VarCharValue": "0.8"
#                     },
#                     {
#                         "VarCharValue": "-1.8904"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Corporate"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Auburn"
#                     },
#                     {
#                         "VarCharValue": "New York"
#                     },
#                     {
#                         "VarCharValue": "13021"
#                     },
#                     {
#                         "VarCharValue": "East"
#                     },
#                     {
#                         "VarCharValue": "Furniture"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "520.05"
#                     },
#                     {
#                         "VarCharValue": "5"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "72.807"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Corporate"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Auburn"
#                     },
#                     {
#                         "VarCharValue": "New York"
#                     },
#                     {
#                         "VarCharValue": "13021"
#                     },
#                     {
#                         "VarCharValue": "East"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "17.97"
#                     },
#                     {
#                         "VarCharValue": "3"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "5.2113"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Second Class"
#                     },
#                     {
#                         "VarCharValue": "Home Office"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Jacksonville"
#                     },
#                     {
#                         "VarCharValue": "Florida"
#                     },
#                     {
#                         "VarCharValue": "32216"
#                     },
#                     {
#                         "VarCharValue": "South"
#                     },
#                     {
#                         "VarCharValue": "Furniture"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "1166.92"
#                     },
#                     {
#                         "VarCharValue": "5"
#                     },
#                     {
#                         "VarCharValue": "0.2"
#                     },
#                     {
#                         "VarCharValue": "131.2785"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "First Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "New York City"
#                     },
#                     {
#                         "VarCharValue": "New York"
#                     },
#                     {
#                         "VarCharValue": "10024"
#                     },
#                     {
#                         "VarCharValue": "East"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "14.624"
#                     },
#                     {
#                         "VarCharValue": "2"
#                     },
#                     {
#                         "VarCharValue": "0.2"
#                     },
#                     {
#                         "VarCharValue": "5.484"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "First Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "San Jose"
#                     },
#                     {
#                         "VarCharValue": "California"
#                     },
#                     {
#                         "VarCharValue": "95123"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "10.23"
#                     },
#                     {
#                         "VarCharValue": "3"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "4.9104"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "First Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "San Jose"
#                     },
#                     {
#                         "VarCharValue": "California"
#                     },
#                     {
#                         "VarCharValue": "95123"
#                     },
#                     {
#                         "VarCharValue": "West"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "154.9"
#                     },
#                     {
#                         "VarCharValue": "5"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "69.705"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Corporate"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Virginia Beach"
#                     },
#                     {
#                         "VarCharValue": "Virginia"
#                     },
#                     {
#                         "VarCharValue": "23464"
#                     },
#                     {
#                         "VarCharValue": "South"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "2715.93"
#                     },
#                     {
#                         "VarCharValue": "7"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "1276.4871"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Corporate"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Virginia Beach"
#                     },
#                     {
#                         "VarCharValue": "Virginia"
#                     },
#                     {
#                         "VarCharValue": "23464"
#                     },
#                     {
#                         "VarCharValue": "South"
#                     },
#                     {
#                         "VarCharValue": "Technology"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "617.97"
#                     },
#                     {
#                         "VarCharValue": "3"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "173.0316"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Henderson"
#                     },
#                     {
#                         "VarCharValue": "Kentucky"
#                     },
#                     {
#                         "VarCharValue": "42420"
#                     },
#                     {
#                         "VarCharValue": "South"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "10.67"
#                     },
#                     {
#                         "VarCharValue": "1"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "4.9082"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Henderson"
#                     },
#                     {
#                         "VarCharValue": "Kentucky"
#                     },
#                     {
#                         "VarCharValue": "42420"
#                     },
#                     {
#                         "VarCharValue": "South"
#                     },
#                     {
#                         "VarCharValue": "Office Supplies"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "36.63"
#                     },
#                     {
#                         "VarCharValue": "3"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "9.8901"
#                     }
#                 ]
#             },
#             {
#                 "Data": [
#                     {
#                         "VarCharValue": "Standard Class"
#                     },
#                     {
#                         "VarCharValue": "Consumer"
#                     },
#                     {
#                         "VarCharValue": "United States"
#                     },
#                     {
#                         "VarCharValue": "Henderson"
#                     },
#                     {
#                         "VarCharValue": "Kentucky"
#                     },
#                     {
#                         "VarCharValue": "42420"
#                     },
#                     {
#                         "VarCharValue": "South"
#                     },
#                     {
#                         "VarCharValue": "Furniture"
#                     },
#                     {},
#                     {
#                         "VarCharValue": "24.1"
#                     },
#                     {
#                         "VarCharValue": "5"
#                     },
#                     {
#                         "VarCharValue": "0.0"
#                     },
#                     {
#                         "VarCharValue": "9.158"
#                     }
#                 ]
#             }
#         ]
#     },
#     "UpdateCount": 0
# }

# %%
# Your Athena table is now ready. You can go to SageMaker Data Wrangler and connect to this delta file through Athena
